# %%
# !pip install langchain-groq
# Out:
# ...
#
#   Attempting uninstall: langsmith
#
#     Found existing installation: langsmith 0.0.87
#
#     Uninstalling langsmith-0.0.87:
#
#       Successfully uninstalled langsmith-0.0.87
#
#    ---------------------------------------- 0/2 [langsmith]
#    ---------------------------------------- 0/2 [langsmith]
#   Attempting uninstall: langchain-core
#    ---------------------------------------- 0/2 [langsmith]
#     Found existing installation: langchain-core 0.1.23
#    ---------------------------------------- 0/2 [langsmith]
#     Uninstalling langchain-core-0.1.23:
#    ---------------------------------------- 0/2 [langsmith]
#       Successfully uninstalled langchain-core-0.1.23
#    ---------------------------------------- 0/2 [langsmith]
#    -------------------- ------------------- 1/2 [langchain-core]
#    -------------------- ------------------- 1/2 [langchain-core]
#    -------------------- ------------------- 1/2 [langchain-core]
# ...

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    temperature=0,
    groq_api_key="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",
    model="openai/gpt-oss-120b"
)

response = llm.invoke("Name the goverment banks in india")
print(response.content)
# Out:
# c:\Users\katak\AppData\Local\Programs\Python\Python314\Lib\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
# Below is the current list (as of 2024) of **government‑owned commercial banks** in India – i.e., the **Public‑Sector Banks (PSBs)** that are majority‑owned by the Union Government (or, in the case of the State Bank of India, its subsidiaries).
#
# | # | Bank (Full Name) | Common Abbreviation | Year of Nationalisation / Merger |
# |---|------------------|---------------------|-----------------------------------|
# | 1 | **State Bank of India** | SBI | 1955 (as Imperial Bank of India) |
# | 2 | **Punjab National Bank** | PNB | 1969 (originally 1894; merged with Oriental Bank of Commerce & United Bank of India in 2020) |
# | 3 | **Bank of Baroda** | BoB | 1960 (merged with Dena Bank & Vijaya Bank in 2019) |
# ...
